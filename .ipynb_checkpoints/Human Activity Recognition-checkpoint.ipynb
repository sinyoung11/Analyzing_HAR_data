# %% [markdown]
# reference: https://www.kaggle.com/code/fahadmehfoooz/human-activity-recognition-with-neural-networks

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Sequential
from keras.layers import Dense,Dropout
from kerastuner.tuners import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters
import os
import warnings
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf
from kerastuner.tuners import RandomSearch
warnings.filterwarnings('ignore')

# %%
# Import the HAR dataset
x_train_file = open('./Data/train/X_train.txt', 'r')
y_train_file = open('./Data/train/y_train.txt', 'r')

x_test_file = open('./Data/test/X_test.txt', 'r')
y_test_file = open('./Data/test/y_test.txt', 'r')

# Create empty lists
x_train = []
y_train = []
x_test = []
y_test = []

# Mapping table for classes
labels = {1:'WALKING', 2:'WALKING UPSTAIRS', 3:'WALKING DOWNSTAIRS',
          4:'SITTING', 5:'STANDING', 6:'LAYING'}

# Loop through datasets
for x in x_train_file:
    x_train.append([float(ts) for ts in x.split()])
    
for y in y_train_file:
    y_train.append(int(y.rstrip('\n')))
    
for x in x_test_file:
    x_test.append([float(ts) for ts in x.split()])
    
for y in y_test_file:
    y_test.append(int(y.rstrip('\n')))
    
# Convert to numpy for efficiency
x_train = np.array(x_train)
y_train = np.array(y_train)
y_train  = y_train -1
print(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)
y_test = y_test -1
print(y_test)
# Out:
# [4 4 4 ... 1 1 1]
# [4 4 4 ... 1 1 1]

# %%
scaling_data = MinMaxScaler()
x_train = scaling_data.fit_transform(x_train)
x_test = scaling_data.fit_transform(x_test)

# %%
model = Sequential()
model.add(Dense(units=64, kernel_initializer='normal', activation='sigmoid', input_dim=x_train.shape[1]))
model.add(Dropout(0.2))
model.add(Dense(units=6, kernel_initializer='normal', activation='softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, batch_size=64, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 115/115 [==============================] - 1s 3ms/step - loss: 1.3114 - accuracy: 0.4574 - val_loss: 1.0459 - val_accuracy: 0.6461
# Epoch 2/10
# 115/115 [==============================] - 0s 1ms/step - loss: 0.9051 - accuracy: 0.7040 - val_loss: 0.7518 - val_accuracy: 0.7730
# Epoch 3/10
# 115/115 [==============================] - 0s 1ms/step - loss: 0.6404 - accuracy: 0.8103 - val_loss: 0.5494 - val_accuracy: 0.8453
# Epoch 4/10
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4866 - accuracy: 0.8576 - val_loss: 0.4782 - val_accuracy: 0.8385
# Epoch 5/10
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3948 - accuracy: 0.8794 - val_loss: 0.4326 - val_accuracy: 0.8432
# Epoch 6/10
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3242 - accuracy: 0.9002 - val_loss: 0.3656 - val_accuracy: 0.8677
# Epoch 7/10
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2897 - accuracy: 0.9086 - val_loss: 0.3764 - val_accuracy: 0.8571
# Epoch 8/10
# 115/115 [==============================] - 0s 1ms/step - loss: 0.2558 - accuracy: 0.9157 - val_loss: 0.3372 - val_accuracy: 0.8748
# Epoch 9/10
# 115/115 [==============================] - 0s 1ms/step - loss: 0.2271 - accuracy: 0.9246 - val_loss: 0.3224 - val_accuracy: 0.8823
# Epoch 10/10
# 115/115 [==============================] - 0s 1ms/step - loss: 0.2096 - accuracy: 0.9282 - val_loss: 0.2736 - val_accuracy: 0.9009

# %%
def build_model(hp):
    model = keras.Sequential()
    for i in range(hp.Int('num_layers',2,25)):
        model.add(layers.Dense(units = hp.Int('units' + str(i), min_value=32, max_value=512, step=32),
                              kernel_initializer=hp.Choice('initializer', ['uniform','normal']),
                              activation = hp.Choice('activation', ['relu', 'sigmoid', 'tanh'])))
        model.add(layers.Dense(6, kernel_initializer= hp.Choice('initializer', ['uniform','normal']), activation = 'softmax'))
        model.add(Dropout(0.2))
        model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
tuner = RandomSearch(build_model, objective='val_accuracy', max_trials =5, executions_per_trial=3,
                    directory='project', project_name = 'Human_activity_recognition')
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 5
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 25, 'step': 1, 'sampling': 'linear'}
# units0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# initializer (Choice)
# {'default': 'uniform', 'conditions': [], 'values': ['uniform', 'normal'], 'ordered': False}
# activation (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'sigmoid', 'tanh'], 'ordered': False}
# units1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}

# %%
tuner.search(x_train, y_train, epochs=10, validation_data = (x_test, y_test))
# Out:
# Trial 5 Complete [00h 01m 01s]
# val_accuracy: 0.18221920728683472
#
# Best val_accuracy So Far: 0.18221920728683472
# Total elapsed time: 00h 03m 26s

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in project\Human_activity_recognition
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 0 summary
# Hyperparameters:
# num_layers: 8
# units0: 352
# initializer: uniform
# activation: sigmoid
# units1: 160
# units2: 32
# units3: 32
# units4: 32
# units5: 32
# units6: 32
# units7: 32
# Score: 0.18221920728683472
#
# Trial 1 summary
# Hyperparameters:
# num_layers: 10
# units0: 96
# initializer: normal
# activation: relu
# units1: 96
# units2: 416
# units3: 96
# units4: 128
# units5: 128
# units6: 384
# units7: 160
# units8: 32
# units9: 32
# Score: 0.18221920728683472
#
# Trial 2 summary
# Hyperparameters:
# num_layers: 19
# units0: 448
# initializer: normal
# activation: tanh
# units1: 224
# units2: 384
# units3: 64
# units4: 64
# units5: 256
# units6: 384
# units7: 512
# units8: 96
# units9: 64
# units10: 32
# units11: 32
# units12: 32
# units13: 32
# units14: 32
# units15: 32
# units16: 32
# units17: 32
# units18: 32
# Score: 0.18221920728683472
#
# Trial 3 summary
# Hyperparameters:
# num_layers: 11
# units0: 288
# initializer: uniform
# activation: relu
# units1: 64
# units2: 160
# units3: 256
# units4: 64
# units5: 160
# units6: 192
# units7: 64
# units8: 96
# units9: 288
# units10: 64
# units11: 128
# units12: 512
# units13: 480
# units14: 416
# units15: 64
# units16: 96
# units17: 160
# units18: 32
# Score: 0.18221920728683472
#
# Trial 4 summary
# Hyperparameters:
# num_layers: 22
# units0: 480
# initializer: uniform
# activation: sigmoid
# units1: 416
# units2: 384
# units3: 384
# units4: 64
# units5: 448
# units6: 352
# units7: 256
# units8: 96
# units9: 160
# units10: 416
# units11: 32
# units12: 128
# units13: 128
# units14: 320
# units15: 32
# units16: 128
# units17: 128
# units18: 192
# units19: 32
# units20: 32
# units21: 32
# Score: 0.18221920728683472

# %%
model = tuner.get_best_models(num_models=1)[0]
history = model.fit(x_
51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4594 - accuracy: 0.1816 - val_loss: 1.7917 - val_accuracy: 0.1822
# Epoch 33/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4609 - accuracy: 0.1806 - val_loss: 1.7914 - val_accuracy: 0.1666
# Epoch 34/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.5397 - accuracy: 0.1922 - val_loss: 1.7932 - val_accuracy: 0.1805
# Epoch 35/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4337 - accuracy: 0.1843 - val_loss: 1.7914 - val_accuracy: 0.1805
# Epoch 36/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4920 - accuracy: 0.1876 - val_loss: 1.7910 - val_accuracy: 0.1666
# Epoch 37/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.3604 - accuracy: 0.1908 - val_loss: 1.7912 - val_accuracy: 0.1805
# Epoch 38/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4765 - accuracy: 0.1870 - val_loss: 1.7913 - val_accuracy: 0.1822
# Epoch 39/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4555 - accuracy: 0.1863 - val_loss: 1.7895 - val_accuracy: 0.1822
# Epoch 40/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4211 - accuracy: 0.1868 - val_loss: 1.7901 - val_accuracy: 0.1805
# Epoch 41/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.5297 - accuracy: 0.1861 - val_loss: 1.7908 - val_accuracy: 0.1822
# Epoch 42/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.3863 - accuracy: 0.1907 - val_loss: 1.7943 - val_accuracy: 0.1822
# Epoch 43/51
# 230/230 [==============================] - 1s 4ms/step - loss: 4.4205 - accuracy: 0.1893 - val_loss: 1.7907 - val_accuracy: 0.1822
# Epoch 44/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4048 - accuracy: 0.1874 - val_loss: 1.7933 - val_accuracy: 0.1822
# Epoch 45/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.5948 - accuracy: 0.1850 - val_loss: 1.7910 - val_accuracy: 0.1805
# Epoch 46/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4854 - accuracy: 0.1906 - val_loss: 1.7915 - val_accuracy: 0.1822
# Epoch 47/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.5611 - accuracy: 0.1800 - val_loss: 1.7917 - val_accuracy: 0.1822
# Epoch 48/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.5032 - accuracy: 0.1857 - val_loss: 1.7928 - val_accuracy: 0.1805
# Epoch 49/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.3810 - accuracy: 0.1916 - val_loss: 1.7911 - val_accuracy: 0.1822
# Epoch 50/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4196 - accuracy: 0.1873 - val_loss: 1.7903 - val_accuracy: 0.1822
# Epoch 51/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.3337 - accuracy: 0.1884 - val_loss: 1.7914 - val_accuracy: 0.1822

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 352)               197824
#
#  dense_1 (Dense)             (None, 6)                 2118
#
#  dropout (Dropout)           (None, 6)                 0
#
#  dense_2 (Dense)             (None, 160)               1120
#
#  dense_3 (Dense)             (None, 6)                 966
#
#  dropout_1 (Dropout)         (None, 6)                 0
#
#  dense_4 (Dense)             (None, 32)                224
#
#  dense_5 (Dense)             (None, 6)                 198
#
#  dropout_2 (Dropout)         (None, 6)                 0
#
#  dense_6 (Dense)             (None, 32)                224
#
#  dense_7 (Dense)             (None, 6)                 198
#
#  dropout_3 (Dropout)         (None, 6)                 0
#
#  dense_8 (Dense)             (None, 32)                224
#
#  dense_9 (Dense)             (None, 6)                 198
#
#  dropout_4 (Dropout)         (None, 6)                 0
#
#  dense_10 (Dense)            (None, 32)                224
#
#  dense_11 (Dense)            (None, 6)                 198
#
#  dropout_5 (Dropout)         (None, 6)                 0
#
#  dense_12 (Dense)            (None, 32)                224
#
#  dense_13 (Dense)            (None, 6)                 198
#
#  dropout_6 (Dropout)         (None, 6)                 0
#
#  dense_14 (Dense)            (None, 32)                224
#
#  dense_15 (Dense)            (None, 6)                 198
#
#  dropout_7 (Dropout)         (None, 6)                 0
#
# =================================================================
# Total params: 204560 (799.06 KB)
# Trainable params: 204560 (799.06 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
Callback = tf.keras.callbacks.EarlyStopping(monitor='accuracy', patience=3)
mo_fitt = model.fit(x_train, y_train, epochs=200, validation_data=(x_test, y_test), callbacks=Callback)
# Out:
# Epoch 1/200
# 230/230 [==============================] - 1s 3ms/step - loss: 4.5814 - accuracy: 0.1831 - val_loss: 1.7924 - val_accuracy: 0.1822
# Epoch 2/200
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4873 - accuracy: 0.1847 - val_loss: 1.7918 - val_accuracy: 0.1666
# Epoch 3/200
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4363 - accuracy: 0.1843 - val_loss: 1.7905 - val_accuracy: 0.1822
# Epoch 4/200
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4074 - accuracy: 0.1877 - val_loss: 1.7902 - val_accuracy: 0.1805
# Epoch 5/200
# 230/230 [==============================] - 1s 3ms/step - loss: 4.3942 - accuracy: 0.1933 - val_loss: 1.7903 - val_accuracy: 0.1805
# Epoch 6/200
# 230/230 [==============================] - 1s 3ms/step - loss: 4.2718 - accuracy: 0.1946 - val_loss: 1.7936 - val_accuracy: 0.1805
# Epoch 7/200
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4385 - accuracy: 0.1868 - val_loss: 1.7923 - val_accuracy: 0.1822
# Epoch 8/200
# 230/230 [==============================] - 1s 3ms/step - loss: 4.5184 - accuracy: 0.1825 - val_loss: 1.7914 - val_accuracy: 0.1805
# Epoch 9/200
# 230/230 [==============================] - 1s 3ms/step - loss: 4.5780 - accuracy: 0.1832 - val_loss: 1.7894 - val_accuracy: 0.1822

# %%
from sklearn.metrics import classification_report, confusion_matrix
# predict 
pred = model.predict(x_test, batch_size = 32)
pred = np.argmax(pred)
# label
y_test = np.argmax(y_test)

print(y_test.shape, pred.shape)

fig = plt.figure(figsize=(6,6))
width = np.shape(conf_mat)[1]
height = np.shape(conf_mat)[0]

res = plt.imshow(np.array(conf_mat), cmap=plt.cm.summer, interpolation='nearest')

for i,row in enumerate(conf_mat):
    for j,c in enumerate(row):
        if c>0:
            plt.text(j-.2, i+.1, c, fontsize=16)

cb = fig.colorbar(res)
plt.title('Confusion Matrix')
plt.xticks(range(6), [l for l in labels.values()], rotation=90)
plt.yticks(range(6), [l for l in labels.values()])
# Out:
# 93/93 [==============================] - 0s 1ms/step
# () ()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 11
#       8 print(y_test.shape, pred.shape)
#      10 fig = plt.figure(figsize=(6,6))
# ---> 11 width = np.shape(conf_mat)[1]
#      12 height = np.shape(conf_mat)[0]
#      14 res = plt.imshow(np.array(conf_mat), cmap=plt.cm.summer, interpolation='nearest')
#
# NameError: name 'conf_mat' is not defined

# %% [markdown]
# reference: https://www.kaggle.com/code/fahadmehfoooz/human-activity-recognition-with-neural-networks

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Sequential
from keras.layers import Dense,Dropout
from kerastuner.tuners import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters
import os
import warnings
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf
from kerastuner.tuners import RandomSearch
warnings.filterwarnings('ignore')

# %%
# Import the HAR dataset
x_train_file = open('./Data/train/X_train.txt', 'r')
y_train_file = open('./Data/train/y_train.txt', 'r')

x_test_file = open('./Data/test/X_test.txt', 'r')
y_test_file = open('./Data/test/y_test.txt', 'r')

# Create empty lists
x_train = []
y_train = []
x_test = []
y_test = []

# Mapping table for classes
labels = {1:'WALKING', 2:'WALKING UPSTAIRS', 3:'WALKING DOWNSTAIRS',
          4:'SITTING', 5:'STANDING', 6:'LAYING'}

# Loop through datasets
for x in x_train_file:
    x_train.append([float(ts) for ts in x.split()])
    
for y in y_train_file:
    y_train.append(int(y.rstrip('\n')))
    
for x in x_test_file:
    x_test.append([float(ts) for ts in x.split()])
    
for y in y_test_file:
    y_test.append(int(y.rstrip('\n')))
    
# Convert to numpy for efficiency
x_train = np.array(x_train)
y_train = np.array(y_train)
y_train  = y_train -1
print(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)
y_test = y_test -1
print(y_test)
# Out:
# [4 4 4 ... 1 1 1]
# [4 4 4 ... 1 1 1]

# %%
scaling_data = MinMaxScaler()
x_train = scaling_data.fit_transform(x_train)
x_test = scaling_data.fit_transform(x_test)

# %%
model = Sequential()
model.add(Dense(units=64, kernel_initializer='normal', activation='sigmoid', input_dim=x_train.shape[1]))
model.add(Dropout(0.2))
model.add(Dense(units=6, kernel_initializer='normal', activation='softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, batch_size=64, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 115/115 [==============================] - 1s 3ms/step - loss: 1.3114 - accuracy: 0.4574 - val_loss: 1.0459 - val_accuracy: 0.6461
# Epoch 2/10
# 115/115 [==============================] - 0s 1ms/step - loss: 0.9051 - accuracy: 0.7040 - val_loss: 0.7518 - val_accuracy: 0.7730
# Epoch 3/10
# 115/115 [==============================] - 0s 1ms/step - loss: 0.6404 - accuracy: 0.8103 - val_loss: 0.5494 - val_accuracy: 0.8453
# Epoch 4/10
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4866 - accuracy: 0.8576 - val_loss: 0.4782 - val_accuracy: 0.8385
# Epoch 5/10
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3948 - accuracy: 0.8794 - val_loss: 0.4326 - val_accuracy: 0.8432
# Epoch 6/10
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3242 - accuracy: 0.9002 - val_loss: 0.3656 - val_accuracy: 0.8677
# Epoch 7/10
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2897 - accuracy: 0.9086 - val_loss: 0.3764 - val_accuracy: 0.8571
# Epoch 8/10
# 115/115 [==============================] - 0s 1ms/step - loss: 0.2558 - accuracy: 0.9157 - val_loss: 0.3372 - val_accuracy: 0.8748
# Epoch 9/10
# 115/115 [==============================] - 0s 1ms/step - loss: 0.2271 - accuracy: 0.9246 - val_loss: 0.3224 - val_accuracy: 0.8823
# Epoch 10/10
# 115/115 [==============================] - 0s 1ms/step - loss: 0.2096 - accuracy: 0.9282 - val_loss: 0.2736 - val_accuracy: 0.9009

# %%
def build_model(hp):
    model = keras.Sequential()
    for i in range(hp.Int('num_layers',2,25)):
        model.add(layers.Dense(units = hp.Int('units' + str(i), min_value=32, max_value=512, step=32),
                              kernel_initializer=hp.Choice('initializer', ['uniform','normal']),
                              activation = hp.Choice('activation', ['relu', 'sigmoid', 'tanh'])))
        model.add(layers.Dense(6, kernel_initializer= hp.Choice('initializer', ['uniform','normal']), activation = 'softmax'))
        model.add(Dropout(0.2))
        model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
tuner = RandomSearch(build_model, objective='val_accuracy', max_trials =5, executions_per_trial=3,
                    directory='project', project_name = 'Human_activity_recognition')
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 5
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 25, 'step': 1, 'sampling': 'linear'}
# units0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# initializer (Choice)
# {'default': 'uniform', 'conditions': [], 'values': ['uniform', 'normal'], 'ordered': False}
# activation (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'sigmoid', 'tanh'], 'ordered': False}
# units1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}

# %%
tuner.search(x_train, y_train, epochs=10, validation_data = (x_test, y_test))
# Out:
# Trial 5 Complete [00h 01m 01s]
# val_accuracy: 0.18221920728683472
#
# Best val_accuracy So Far: 0.18221920728683472
# Total elapsed time: 00h 03m 26s

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in project\Human_activity_recognition
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 0 summary
# Hyperparameters:
# num_layers: 8
# units0: 352
# initializer: uniform
# activation: sigmoid
# units1: 160
# units2: 32
# units3: 32
# units4: 32
# units5: 32
# units6: 32
# units7: 32
# Score: 0.18221920728683472
#
# Trial 1 summary
# Hyperparameters:
# num_layers: 10
# units0: 96
# initializer: normal
# activation: relu
# units1: 96
# units2: 416
# units3: 96
# units4: 128
# units5: 128
# units6: 384
# units7: 160
# units8: 32
# units9: 32
# Score: 0.18221920728683472
#
# Trial 2 summary
# Hyperparameters:
# num_layers: 19
# units0: 448
# initializer: normal
# activation: tanh
# units1: 224
# units2: 384
# units3: 64
# units4: 64
# units5: 256
# units6: 384
# units7: 512
# units8: 96
# units9: 64
# units10: 32
# units11: 32
# units12: 32
# units13: 32
# units14: 32
# units15: 32
# units16: 32
# units17: 32
# units18: 32
# Score: 0.18221920728683472
#
# Trial 3 summary
# Hyperparameters:
# num_layers: 11
# units0: 288
# initializer: uniform
# activation: relu
# units1: 64
# units2: 160
# units3: 256
# units4: 64
# units5: 160
# units6: 192
# units7: 64
# units8: 96
# units9: 288
# units10: 64
# units11: 128
# units12: 512
# units13: 480
# units14: 416
# units15: 64
# units16: 96
# units17: 160
# units18: 32
# Score: 0.18221920728683472
#
# Trial 4 summary
# Hyperparameters:
# num_layers: 22
# units0: 480
# initializer: uniform
# activation: sigmoid
# units1: 416
# units2: 384
# units3: 384
# units4: 64
# units5: 448
# units6: 352
# units7: 256
# units8: 96
# units9: 160
# units10: 416
# units11: 32
# units12: 128
# units13: 128
# units14: 320
# units15: 32
# units16: 128
# units17: 128
# units18: 192
# units19: 32
# units20: 32
# units21: 32
# Score: 0.18221920728683472

# %%
model = tuner.get_best_models(num_models=1)[0]
history = model.fit(x_train, y_train, epochs=51, validation_data=(x_test, y_test))
# Out:
# Epoch 1/51
# 230/230 [==============================] - 3s 4ms/step - loss: 4.4511 - accuracy: 0.1881 - val_loss: 1.7890 - val_accuracy: 0.1822
# Epoch 2/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.5092 - accuracy: 0.1840 - val_loss: 1.7903 - val_accuracy: 0.1805
# Epoch 3/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4642 - accuracy: 0.1857 - val_loss: 1.7930 - val_accuracy: 0.1666
# Epoch 4/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.5392 - accuracy: 0.1848 - val_loss: 1.7946 - val_accuracy: 0.1805
# Epoch 5/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4222 - accuracy: 0.1888 - val_loss: 1.7929 - val_accuracy: 0.1805
# Epoch 6/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4954 - accuracy: 0.1831 - val_loss: 1.7898 - val_accuracy: 0.1822
# Epoch 7/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.3597 - accuracy: 0.1878 - val_loss: 1.7906 - val_accuracy: 0.1822
# Epoch 8/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4025 - accuracy: 0.1827 - val_loss: 1.7911 - val_accuracy: 0.1822
# Epoch 9/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4227 - accuracy: 0.1817 - val_loss: 1.7911 - val_accuracy: 0.1805
# Epoch 10/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4247 - accuracy: 0.1888 - val_loss: 1.7910 - val_accuracy: 0.1805
# Epoch 11/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4103 - accuracy: 0.1882 - val_loss: 1.7950 - val_accuracy: 0.1666
# Epoch 12/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.3232 - accuracy: 0.1857 - val_loss: 1.7946 - val_accuracy: 0.1822
# Epoch 13/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4430 - accuracy: 0.1888 - val_loss: 1.7928 - val_accuracy: 0.1805
# Epoch 14/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4992 - accuracy: 0.1869 - val_loss: 1.7937 - val_accuracy: 0.1822
# Epoch 15/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.
51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.3810 - accuracy: 0.1916 - val_loss: 1.7911 - val_accuracy: 0.1822
# Epoch 50/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4196 - accuracy: 0.1873 - val_loss: 1.7903 - val_accuracy: 0.1822
# Epoch 51/51
# 230/230 [==============================] - 1s 3ms/step - loss: 4.3337 - accuracy: 0.1884 - val_loss: 1.7914 - val_accuracy: 0.1822

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 352)               197824
#
#  dense_1 (Dense)             (None, 6)                 2118
#
#  dropout (Dropout)           (None, 6)                 0
#
#  dense_2 (Dense)             (None, 160)               1120
#
#  dense_3 (Dense)             (None, 6)                 966
#
#  dropout_1 (Dropout)         (None, 6)                 0
#
#  dense_4 (Dense)             (None, 32)                224
#
#  dense_5 (Dense)             (None, 6)                 198
#
#  dropout_2 (Dropout)         (None, 6)                 0
#
#  dense_6 (Dense)             (None, 32)                224
#
#  dense_7 (Dense)             (None, 6)                 198
#
#  dropout_3 (Dropout)         (None, 6)                 0
#
#  dense_8 (Dense)             (None, 32)                224
#
#  dense_9 (Dense)             (None, 6)                 198
#
#  dropout_4 (Dropout)         (None, 6)                 0
#
#  dense_10 (Dense)            (None, 32)                224
#
#  dense_11 (Dense)            (None, 6)                 198
#
#  dropout_5 (Dropout)         (None, 6)                 0
#
#  dense_12 (Dense)            (None, 32)                224
#
#  dense_13 (Dense)            (None, 6)                 198
#
#  dropout_6 (Dropout)         (None, 6)                 0
#
#  dense_14 (Dense)            (None, 32)                224
#
#  dense_15 (Dense)            (None, 6)                 198
#
#  dropout_7 (Dropout)         (None, 6)                 0
#
# =================================================================
# Total params: 204560 (799.06 KB)
# Trainable params: 204560 (799.06 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
Callback = tf.keras.callbacks.EarlyStopping(monitor='accuracy', patience=3)
mo_fitt = model.fit(x_train, y_train, epochs=200, validation_data=(x_test, y_test), callbacks=Callback)
# Out:
# Epoch 1/200
# 230/230 [==============================] - 1s 3ms/step - loss: 4.5814 - accuracy: 0.1831 - val_loss: 1.7924 - val_accuracy: 0.1822
# Epoch 2/200
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4873 - accuracy: 0.1847 - val_loss: 1.7918 - val_accuracy: 0.1666
# Epoch 3/200
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4363 - accuracy: 0.1843 - val_loss: 1.7905 - val_accuracy: 0.1822
# Epoch 4/200
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4074 - accuracy: 0.1877 - val_loss: 1.7902 - val_accuracy: 0.1805
# Epoch 5/200
# 230/230 [==============================] - 1s 3ms/step - loss: 4.3942 - accuracy: 0.1933 - val_loss: 1.7903 - val_accuracy: 0.1805
# Epoch 6/200
# 230/230 [==============================] - 1s 3ms/step - loss: 4.2718 - accuracy: 0.1946 - val_loss: 1.7936 - val_accuracy: 0.1805
# Epoch 7/200
# 230/230 [==============================] - 1s 3ms/step - loss: 4.4385 - accuracy: 0.1868 - val_loss: 1.7923 - val_accuracy: 0.1822
# Epoch 8/200
# 230/230 [==============================] - 1s 3ms/step - loss: 4.5184 - accuracy: 0.1825 - val_loss: 1.7914 - val_accuracy: 0.1805
# Epoch 9/200
# 230/230 [==============================] - 1s 3ms/step - loss: 4.5780 - accuracy: 0.1832 - val_loss: 1.7894 - val_accuracy: 0.1822

# %%
from sklearn.metrics import classification_report, confusion_matrix
# predict 
pred = model.predict(x_test, batch_size = 32)
pred = np.argmax(pred)
# label
y_test = np.argmax(y_test)

print(y_test.shape, pred.shape)

fig = plt.figure(figsize=(6,6))
width = np.shape(conf_mat)[1]
height = np.shape(conf_mat)[0]

res = plt.imshow(np.array(conf_mat), cmap=plt.cm.summer, interpolation='nearest')

for i,row in enumerate(conf_mat):
    for j,c in enumerate(row):
        if c>0:
            plt.text(j-.2, i+.1, c, fontsize=16)

cb = fig.colorbar(res)
plt.title('Confusion Matrix')
plt.xticks(range(6), [l for l in labels.values()], rotation=90)
plt.yticks(range(6), [l for l in labels.values()])
# Out:
# 93/93 [==============================] - 0s 1ms/step
# () ()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 11
#       8 print(y_test.shape, pred.shape)
#      10 fig = plt.figure(figsize=(6,6))
# ---> 11 width = np.shape(conf_mat)[1]
#      12 height = np.shape(conf_mat)[0]
#      14 res = plt.imshow(np.array(conf_mat), cmap=plt.cm.summer, interpolation='nearest')
#
# NameError: name 'conf_mat' is not defined
